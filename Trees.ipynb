# %% [markdown]
# <a href="https://colab.research.google.com/github/musiniharish/-Loan_approval_prediction/blob/main/Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# class Node:
#   def __init__(self, value):
#     self.value=value
#     self.left=None
#     self.right=None
# class Bynarytree:
#   def __init__(self):
#     self.root=None


#   def insert(self,value):
#     self.root=self._insert(self.root,value)

#   def _insert(self,root,value):
#     if root is None:
#       return Node(value)

#     if value<root.value:
#       root.left=self._insert(root.left,value)
#     else:
#       root.right=self._insert(root.right,value)

#     return root

  # def inorder(self):
  #   self._inorder(self.root)

  # def _inorder(self,root):
  #   if root is None:
  #     return

  #   self._inorder(root.left)
  #   print(root.value)
  #   self._inorder(root.right)


  # def preorder(self):

  #   self._preorder(self.root)

  # def _preorder(self,root):
  #   if root is None:
  #     return

  #   print(root.value,end=" ")
  #   self._preorder(root.left)
  #   self._preorder(root.right)


  # def postorder(self):
  #   self._postorder(self.root)


  # def _postorder(self,root):
  #   if root is None:
  #     return

  #   self._postorder(root.left)
  #   print(root.value)
  #   self._postorder(root.right)



  def height(self):
    return self._height(self.root)


  def _height(self,root):
    if root is None:
      return 0

    left_h=self.height(root.left)
    right_h=self.height(root.right)

    return 1+max(left_h,right_h)













# ob.inorder()
# ob.preorder()
# ob.postorder()


# print(ob.height())
# Out:
# 4
# enter the value1
# enter the value2
# enter the value3
# enter the value4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1571986421.py in <cell line: 0>()
#      97
#      98
# ---> 99 print(ob.height())
#     100
#     101
#
# /tmp/ipython-input-1571986421.py in height(self)
#      63
#      64   def height(self):
# ---> 65     return self._height(self.root)
#      66
#      67
#
# /tmp/ipython-input-1571986421.py in _height(self, root)
#      70       return
#      71
# ---> 72     left_h=self.height(root.left)
#      73     right_h=self.height(root.right)
#      74
#
# TypeError: Bynarytree.height() takes 1 positional argument but 2 were given

# %%
class Node:
  def __init__(self,value):
    self.value=value
    self.left=None
    self.right=None


class Binarytree:
  def __init__(self):
    self.root=None

  def insert(self,value):
    self.root=self._insert(self.root,value)

  def _insert(self,root,value):
    if root is None:
      return Node(value)


    if value<root.value:
      root.left=self._insert(root.left,value)

    else:
      root.right=self._insert(root.right,value)
    return root


  # def height(self):
  #   return self._height(self.root)


  # def _height(self,root):
  #   if root is None:
  #     return 0

  #   left_h=self._height(root.left)
  #   right_h=self._height(root.right)

  #   return 1+max(left_h,right_h)


def count_node(self):
 return  self._count(self.root)

def _count_count(self,root):
  if root is None:
    return 0

  return 1+self._count_node(root.left) + self.count_node(root.right)







ob=Binarytree()
n=int(input("enter the n value"))

for i in range(n):
  val=int(input("enter the node"))
  ob.insert(val)

# print("height of tree",ob.height())
print("count",count_node())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4292985319.py in <cell line: 0>()
#      56
#      57 ob=Binarytree()
# ---> 58 n=int(input("enter the n value"))
#      59
#      60 for i in range(n):
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
class Node:
  def __init__(self,value):
    self.value=value
    self.left=None
    self.right=None


class BinaryTree:
    def __init__(self):
      self.root=None


    def insert(self,value):
      self.root=self._insert(self.root,value)


    def _insert(self,root,value):
      if root is None:
        return Node(value)

      if value < root.value:
        root.left=self._insert(root.left,value)

      else:
        root.right=self._insert(root.right,value)


      return root

    def inorder(self):
      self._inorder(self.root)

    def _inorder(self,root):
      if root is None:
        return

      self._inorder(root.left)
      print(root.value)
      self._inorder(root.right)

# height of a tree
    def height(self):
      return self._height(self.root)

    def _height(self,root):
      if root is None:
        return 0

      left_he=self._height(root.left)
      right_he=self._height(root.right)

      return 1+max(left_he,right_he)





ob=BinaryTree()

n=int(input())
for i in range(n):
  val=int(input("enter the value"))
  ob.insert(val)

# ob.inorder()
print(ob.height())
# Out:
# 5
# enter the value5
# enter the value4
# enter the value3
# enter the value2
# enter the value1
# 5

# %%
class Node:
  def __init__(self,value):
    self.value=value
    self.left=None
    self.right=None

class BinaryTree:
  def __init__(self):
    self.root=None

  def insert(self,value):
    self.root=self._insert(self.root,value)

  def _insert(self,root,value):
    if root is None:
      return Node(value)


    if value<root.value:
      root.left=self._insert(root.left,value)
    else:
      root.right=self._insert(root.right,value)

    return root


  def inorder(self):
    self._inorder(self.root)

  def _inorder(self,root):
    if root is None:
      return 0

    self._inorder(root.left)
    print(root.value)
    self._inorder(root.right)
# count leaf nodes
  def count_leaf(self):
    return self._count_leaf(self.root)

  def _count_leaf(self,root):
    if root is None:
      return 0

    if root.left is None and root.right is None:
      return 1


    return self._count_leaf(root.left)+self._count_leaf(root.right)




ob=BinaryTree()
n=int(input())
for i in range(n):
  value=int(input("enter the value"))
  ob.insert(value)

ob.inorder()
print("count leaf",ob.count_leaf())
# Out:
# 5
# enter the value10
# enter the value5
# enter the value15
# enter the value3
# enter the value7
# 3
# 5
# 7
# 10
# 15
# count leaf 3

# %%
class Node:
  def __init__(self,value):
    self.value=value
    self.left=None
    self.right=None

class BinaryTree:
  def __init__(self):
    self.root=None

  def insert(self,value):
    self.root=self._insert(self.root,value)

  def _insert(self,root,value):
    if root is None:
      return Node(value)

    if value<root.value:
      root.left=self._insert(root.left,value)
    else:
      root.right=self._insert(root.right,value)

    return root

# search an element in a binary tree

  def search(self,key):
    return self._search(self.root,key)

  def _search(self,root,key):
    if root is None:
      return False

    if key==root.value:
      return True

    if key<root.value:
      return self._search(root.left,key)
    else:
      return self._search(root.right,key)

ob=BinaryTree()
n=int(input())
for i in range(n):
  val=int(input("enter the val"))
  ob.insert(val)
key=int(input("enter the key"))
print(ob.search(key))
# Out:
# 5
# enter the val10
# enter the val5
# enter the val15
# enter the val3
# enter the val7
# enter the key9
# False

# %%
class Node:
  def __init__(self,value):
    self.value=value
    self.left=None
    self.right=None

class BinaryTree:
  def __init__(self):
    self.root=None

  def insert(self,value):
    self.root=self._insert(self.root,value)

  def _insert(self,root,value):
    if root is None:
      return Node(value)

    if value<root.value:
      root.left=self._insert(root.left,value)
    else:
      root.right=self._insert(root.right,value)

    return root

  def inorder(self):
    self._inorder(self.root)

  def _inorder(self,root):
    if root is None:
      return

    self._inorder(root.left)
    print(root.value)
    self._inorder(root.right)


  # delete a node from binary tree


  def delete(self,key):
    self.root=self._delete(self.root,key)

  def _delete(self,root,key):
    if root is None:
      return None

    if key<root.value:
      root.left=self._delete(root.left,key)
    elif key>root.value:
      root.right=self._delete(root.right,key)

    else:
      if root.left is None:
        return root.right
      if root.right is None:
        return root.left

      sucessor=self.minVlaueNode(root.right)
      root.value=sucessor.value
      root.right=self._delete(root.right,sucessor.value)

    return root

  def minVlaueNode(self, node):
      current=node
      while current.left:
        current=current.left
      return current



ob=BinaryTree()
n=int(input())
for i in range(n):
  val=int(input("enter the value"))
  ob.insert(val)
ob.inorder()
key=int(input("enter the node delete"))
ob.delete(key)
ob.inorder()
# Out:
# 5
# enter the value10
# enter the value15
# enter the value12
# enter the value18
# enter the value5
# 5
# 10
# 12
# 15
# 18
# enter the node delete15
# 5
# 10
# 12
# 18

# %%
class Node:
  def __init__(self,value):
    self.value=value
    self.left=None
    self.right=None
class BinaryTree:
  def __init__(self):
    self.root=None

  def insert(self,value):
    self.root=self._insert(self.root,value)

  def _insert(self,root,value):
    if root is None:
      return Node(value)

    if value<root.value:
      root.left=self._insert(root.left,value)
    else:
      root.right=self._insert(root.right,value)


    return root


  def inorder(self):
    self._inorder(self.root)


  def _inorder(self,root):
    if root is None:
      return

    self._inorder(root.left)
    print(root.value,end=" ")
    self._inorder(root.right)

#  find min and max value in binary tree

  def findMin(self):
    current=self.root
    if current is None:
      return None
    while current.left:
      current=current.left
    return current.value

  def findmax(self):
    current=self.root
    if current.right:
      return None
    while current.right:
      current=current.right
    return current.value





ob=BinaryTree()
n=int(input())
for i in range(n):
  val=int(input("enter the value"))
  ob.insert(val)

ob.inorder()
print()
print("min value:",ob.findMin())
print("max value:",ob.findmax())
# Out:
# 5
# enter the value5
# enter the value4
# enter the value3
# enter the value2
# enter the value1
# 1 2 3 4 5
# min value: 1
# max value: 5

# %%
class Node:
  def __init__(self,value):
    self.value=value
    self.left=None
    self.right=None

class BinaryTree:
  def __init__(self):
    self.root=None

  def insert(self,value):
    self.root=self._insert(self.root,value)

  def _insert(self,root,value):
    if root is None:
      return Node(value)

    if value <root.value:
      root.left=self._insert(root.left,value)
    else:
      root.right=self._insert(root.right,value)


    return root


  def inorder(self):
    self._inorder(self.root)

  def _inorder(self,root):
    if root is None:
      return

    self._inorder(root.left)
    print(root.value)
    self._inorder(root.right)


# sum of nodes

  def sum_node(self):
    return self._sum_node(self.root)

  def _sum_node(self,root):
    if root is None:
      return 0

    return root.value+self._sum_node(root.left)+self._sum_node(root.right)

# count non leaf nodes
  def count_non_leaf(self):
    return self._count_non_leaf(self.root)

  def _count_non_leaf(self,root):
    if root is None:
      return 0

    if root.left and root.right is None:
      return 0

    return 1+self._count_non_leaf(root.left)+self._count_non_leaf(root.right)

# mirror of a binary tree
  def mirror(self):
    self._mirror(self.root)

  def _mirror(self,root):
    if root is None:
      return 0

    self._mirror(root.left)
    self._mirror(root.right)

    root.left,root.right=root.right,root.left




ob=BinaryTree()
n=int(input("enter the nodes"))
for i in range(n):
  val=int(input("enter the val"))
  ob.insert(val)

ob.inorder()
print("sum of nodes",ob.sum_node())
print("no of non leaf nodes",ob.count_non_leaf())
print("Before mirror (inorder):")
ob.inorder()
ob.mirror()

print("After mirror (inorder):")
ob.inorder()
# Out:
# enter the nodes6
# enter the val10
# enter the val5
# enter the val3
# enter the val7
# enter the val15
# enter the val25
# 3
# 5
# 7
# 10
# 15
# 25
# sum of nodes 65
# no of non leaf nodes 6
# Before mirror (inorder):
# 3
# 5
# 7
# 10
# 15
# 25
# After mirror (inorder):
# 25
# 15
# 10
# 7
# 5
# 3

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

class BinaryTree:
    def __init__(self):
        self.root = None

    def insert(self, value):
        self.root = self._insert(self.root, value)

    def _insert(self, root, value):
        if root is None:
            return Node(value)

        if value < root.value:
            root.left = self._insert(root.left, value)
        else:
            root.right = self._insert(root.right, value)

        return root

    def inorder(self):
        self._inorder(self.root)

    def _inorder(self, root):
        if root is None:
            return
        self._inorder(root.left)
        print(root.value, end=" ")
        self._inorder(root.right)

# least common ansister
    def Lca(self, n1, n2):
        return self._Lca(self.root, n1, n2)

    def _Lca(self, root, n1, n2):
        if root is None:
            return None

        if n1 < root.value and n2 < root.value:
            return self._Lca(root.left, n1, n2)

        if n1 > root.value and n2 > root.value:
            return self._Lca(root.right, n1, n2)

        return root




ob = BinaryTree()
n = int(input("Enter the size: "))

for i in range(n):
    val = int(input("Enter the value: "))
    ob.insert(val)

print("\nInorder Traversal:")
ob.inorder()

print("\n\nEnter two values to find LCA:")
a = int(input("Enter n1: "))
b = int(input("Enter n2: "))

lca_node = ob.Lca(a, b)

if lca_node:
    print("\nLCA is:", lca_node.value)
else:
    print("\nLCA not found")
# Out:
# Enter the size: 5
# Enter the value: 20
# Enter the value: 10
# Enter the value: 30
# Enter the value: 5
# Enter the value: 15
#
# Inorder Traversal:
# 5 10 15 20 30
#
# Enter two values to find LCA:
# Enter n1: 5
# Enter n2: 15
#
# LCA is: 10
